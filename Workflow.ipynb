# %% [markdown]
# # CIFAR-10 images classification using Deep Learning

# %% [markdown]
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.

# %% [markdown]
# ![cifar](Images/cifar_10.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Load the data

# %%
from loaders import load_cifar_10

# %%
(x_train, y_train), (x_test, y_test) = load_cifar_10()

# %% [markdown]
# ## Visualize data

# %%
from visualize import display_some_images

# %%
display_some_images(x_train, y_train, 6)

# %%
from models import CifarModel

# %%
model = CifarModel((32, 32, 3), [200, 150], 10)

# %%
model.save('cifar_model')

# %%
model.compile(lr=0.0001)

# %%
model.train(x_train, y_train)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 2s 1ms/step - loss: 2.3026 - accuracy: 0.0984
# Epoch 2/10
# 1563/1563 [==============================] - 2s 1ms/step - loss: 2.3026 - accuracy: 0.0974
# Epoch 3/10
# 1563/1563 [==============================] - 1s 903us/step - loss: 2.3026 - accuracy: 0.0980
# Epoch 4/10
# 1563/1563 [==============================] - 2s 1ms/step - loss: 2.3026 - accuracy: 0.0961
# Epoch 5/10
# 1563/1563 [==============================] - 1s 860us/step - loss: 2.3026 - accuracy: 0.0959
# Epoch 6/10
# 1563/1563 [==============================] - 2s 1ms/step - loss: 2.3026 - accuracy: 0.0971
# Epoch 7/10
# 1563/1563 [==============================] - 2s 1ms/step - loss: 2.3026 - accuracy: 0.0991
# Epoch 8/10
# 1563/1563 [==============================] - 1s 909us/step - loss: 2.3026 - accuracy: 0.0973
# Epoch 9/10
# 1563/1563 [==============================] - 1s 900us/step - loss: 2.3026 - accuracy: 0.0957
# Epoch 10/10
# 1563/1563 [==============================] - 1s 938us/step - loss: 2.3026 - accuracy: 0.0961

# %% [markdown]
# ## Evaluate the model

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 0s 789us/step - loss: 2.3026 - accuracy: 0.1000

# %% [markdown]
# ## Make prediction

# %%
a = model.plot_predictions(x_test, y_test, nb_imgs=20)
