# %% [markdown]
# # CIFAR-10 images classification using Deep Learning

# %% [markdown]
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.

# %% [markdown]
# ![cifar](Images/cifar_10.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Load the data

# %%
from loaders import load_cifar_10

# %%
(x_train, y_train), (x_test, y_test) = load_cifar_10()

# %% [markdown]
# ## Visualize data

# %%
from visualize import display_some_images

# %%
display_some_images(x_train, y_train, 6)

# %%
from models import CifarModel

# %%
model = CifarModel((32, 32, 3),[32, 32, 64, 64], [3, 3, 3, 3], [1, 2, 1, 2], 10)

# %% [markdown]
# ## Compile the model

# %%
model.compile(lr=0.0005)

# %% [markdown]
# ## Train the model

# %%
#model.train(x_train, y_train, location='cifar_model', epochs=5)
# Out:
# Epoch 1/5
# 782/782 [==============================] - 143s 180ms/step - loss: 1.2260 - accuracy: 0.5636
#
# Epoch 00001: saving model to models_info\cifar_model\weights\weights.h5
# Epoch 2/5
# 782/782 [==============================] - 142s 181ms/step - loss: 1.0144 - accuracy: 0.6431
#
# Epoch 00002: saving model to models_info\cifar_model\weights\weights.h5
# Epoch 3/5
# 782/782 [==============================] - 141s 180ms/step - loss: 0.9094 - accuracy: 0.6844
#
# Epoch 00003: saving model to models_info\cifar_model\weights\weights.h5
# Epoch 4/5
# 782/782 [==============================] - 140s 179ms/step - loss: 0.8350 - accuracy: 0.7078
#
# Epoch 00004: saving model to models_info\cifar_model\weights\weights.h5
# Epoch 5/5
# 782/782 [==============================] - 142s 181ms/step - loss: 0.7789 - accuracy: 0.7264
#
# Epoch 00005: saving model to models_info\cifar_model\weights\weights.h5

# %% [markdown]
# ## Save the model

# %%
model.save('cifar_model')

# %% [markdown]
# ## Evaluate the model

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 6s 17ms/step - loss: 1.0280 - accuracy: 0.6581

# %% [markdown]
# ## Make prediction

# %%
a = model.plot_predictions(x_test, y_test, nb_imgs=10)

# %% [markdown]
# ### Load the pre-trained model

# %%
from models.cifar_model import CifarModel
from loaders import load_model

# %%
model = load_model(CifarModel, 'cifar_model')

# %%
model.plot_predictions(x_test, y_test, nb_imgs=10)
